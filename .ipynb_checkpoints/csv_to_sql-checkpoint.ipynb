# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_data/cleaned_naukri_dataset.csv')

# %%
df.head()
# Out:
#              company                      location      education  \
# 0                UPL  bengaluru,bengaluru, mumbai    postgraduate
# 1            Walmart           bengaluru,bengaluru   postgraduate
# 2  SAP India Pvt.Ltd           bengaluru,bengaluru  undergraduate
# 3                UPL  bengaluru,bengaluru, mumbai    postgraduate
# 4            Walmart           bengaluru,bengaluru  undergraduate
#
#                                               skills   job_type     salary  \
# 0  python, mlt, statistical modeling, machine lea...   contract   939957.0
# 1  data science, machine learning, python, azure,...   contract  2060767.0
# 2  python, it skills, testing, cloud, product man...  full-time   698970.0
# 3  python, machine learning, data science, data a...  full-time   529674.0
# 4  it skills, python, data science, machine learn...   contract  2163829.0
#
#   job_experience                                           job_role  \
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(f'mysql+pymysql://root:password@localhost:3306/ds_data')

# %%
df.to_sql(name='job_data',con=engine,if_exists='replace',index=False)
# Out:
# 12000
